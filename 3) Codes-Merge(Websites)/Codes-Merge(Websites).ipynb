# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Function to scrape CBR/Anime
def scrape_cbr_anime():
    print("CBR/Anime:")
    base_url = 'https://www.cbr.com/'

    # Replace 'your_url_here' with the actual URL of the website you want to scrape
    url = 'https://www.cbr.com/category/anime/'  # Replace with the actual URL

    # Send an HTTP GET request to the website
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find and print the titles, links, and dates of the articles
        article_blocks = soup.find_all('div', class_='w-display-card-content')  # Replace with the actual HTML element and class name
        for block in article_blocks:
            title_element = block.find('h5', class_='display-card-title').find('a')
            title = title_element.text.strip()
            relative_link = title_element['href']  # Get the relative link
            full_link = base_url + relative_link  # Add the base URL to the relative link
            date_element = block.find('time', class_='display-card-date')['datetime']
            date = date_element.split('T')[0]  # Extract date part from the datetime attribute
            print(f"Title: {title}")
            print(f"Link: {full_link}")  # Print the full link
            print(f"Date: {date}")
            print()  # Add an empty line for better readability
    else:
        print('Failed to retrieve the webpage. Status code:', response.status_code)

# Function to scrape Hashnode/Data Science
def scrape_hashnode_data_science():
    print("\nHashnode/Data Science:")
    base_url = 'https://hashnode.com/n/data-science'

    # Replace 'your_url_here' with the actual URL of the website you want to scrape
    url = 'https://hashnode.com/n/data-science'  # Replace with the actual URL

    # Send an HTTP GET request to the website
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find and print the post titles, URLs, and dates
        post_sections = soup.find_all('section', class_='flex flex-col gap-2 sm:gap-4')  # Replace with the actual HTML element and class name
        for section in post_sections:
            title_element = section.find('h1', class_='font-heading text-base sm:text-xl font-semibold sm:font-bold text-slate-700 dark:text-slate-200 hn-break-words cursor-pointer')
            title = title_element.text.strip()
            link_element = title_element.find_parent('a', href=True)
            link = link_element['href']
            date_element = section.find('p', class_='text-sm text-slate-500 dark:text-slate-400 font-normal')
            date = date_element.text.strip()
            print(f"Title: {title}")
            print(f"Link: {link}")
            print(f"Date: {date}")
            print()  # Add an empty line for better readability
    else:
        print('Failed to retrieve the webpage. Status code:', response.status_code)


# Function to scrape Interesting Engineering
def scrape_interesting_engineering():
    print("\nInteresting Engineering:")

    # Base URL to prepend to relative links
    base_url = 'https://interestingengineering.com/'

    # Replace 'your_url_here' with the actual URL of the website you want to scrape
    url = 'https://interestingengineering.com/news/page/1'  # Replace with the actual URL

    # Send an HTTP GET request to the website
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find and print the article titles, URLs, and date information
        article_blocks = soup.find_all('div', class_='Category_result__description__iz_rw')  # Replace with the actual HTML element and class name
        for block in article_blocks:
            title_link_element = block.find('a', href=True)
            title = title_link_element.find('h2', class_='Category_result__header__HQgVv').text.strip()
            link = urljoin(base_url, title_link_element['href'])  # Prepend base URL to relative links
            date_element = block.find('span', class_='Category_result__author__publishTime__nwLBU')
            date = date_element.text.strip()
            print(f"Title: {title}")
            print(f"Link: {link}")
            print(f"Date: {date}")
            print()  # Add an empty line for better readability
    else:
        print('Failed to retrieve the webpage. Status code:', response.status_code)


# Function to scrape Wired/Science
def scrape_wired_science():
    print("\nWired/Science:")
    base_url = 'https://www.wired.com/category/science/'

    # Replace 'your_url_here' with the actual URL of the website you want to scrape
    url = 'https://www.wired.com/category/science/'  # Replace with the actual URL

    # Send an HTTP GET request to the website
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find and print the article titles, URLs, and categories
        article_blocks = soup.find_all('div', class_='SummaryItemContent-eiDYMl')  # Replace with the actual HTML element and class name
        for block in article_blocks:
            title_element = block.find('h3', class_='SummaryItemHedBase-hiFYpQ')
            title = title_element.text.strip()
            link_element = block.find('a', class_='SummaryItemHedLink-civMjp')
            relative_link = link_element['href']  # Get the relative link
            full_link = urljoin(base_url, relative_link)  # Add the base URL to the relative link
            category_element = block.find('span', class_='RubricName-fVtemz')
            category = category_element.text.strip() if category_element else "N/A"  # Handle missing category
            print(f"Title: {title}")
            print(f"Link: {full_link}")  # Print the full link
            print(f"Category: {category}")
            print()  # Add an empty line for better readability
    else:
        print('Failed to retrieve the webpage. Status code:', response.status_code)

# Function to scrape TechCrunch
def scrape_techcrunch_startups():
    print("\nTechCrunch/Startups:")
    base_url = 'https://techcrunch.com/category/startups/'

    # Replace 'your_url_here' with the actual URL of the website you want to scrape
    url = 'https://techcrunch.com/category/startups/'

    # Send an HTTP GET request to the website
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find and print the titles, links, and dates of the blog posts
        post_blocks = soup.find_all('div', class_='post-block')  # Replace with the actual HTML element and class name
        for block in post_blocks:
            title = block.find('h2', class_='post-block__title').text.strip()
            link = block.find('a', class_='post-block__title__link')['href']
            date_element = block.find('time')
            date = date_element.text  # Extract date part from the datetime attribute
            print(f"Title: {title}")
            print(f"Link: {link}")
            print(f"Date: {date}")
            print()  # Add an empty line for better readability
    else:
        print('Failed to retrieve the webpage. Status code:', response.status_code)


# Call the scraping functions for each site
scrape_cbr_anime()
scrape_hashnode_data_science()
scrape_interesting_engineering()
scrape_wired_science()
scrape_techcrunch_startups()
# Out:
# CBR/Anime:
# Title: The 10 Best My Hero Academia Villains & Their Birthdays, Height, and Zodiac Signs
# Link: https://www.cbr.com//mha-villains-birthday-height-zodiac-signs/
# Date: 2023-09-21
#
# Title: 10 Anime Characters Who Are More Famous Than Their Actual Series
# Link: https://www.cbr.com//anime-characters-more-iconic-than-their-series/
# Date: 2023-09-20
#
# Title: 10 Anime Villains Who Don't Deserve Their Bad Reputation
# Link: https://www.cbr.com//anime-villains-who-deserve-better-reputations/
# Date: 2023-09-20
#
# Title: Crunchyroll Unveils Its Autumn 2023 Anime Lineup
# Link: https://www.cbr.com//crunchyroll-autumn-2023-anime-lineup/
# Date: 2023-09-20
#
# Title: Dragon Ball Super Chapter 97 Recap & Spoilers: Rampaging Cell Max
# Link: https://www.cbr.com//dbs-97-spoilers/
# Date: 2023-09-20
#
# Title: 10 Sci-Fi Anime That Are Just as Good as Star Wars (If Not Better)
# Link: https://www.cbr.com//sci-fi-anime-like-star-wars/
# Date: 2023-09-20
#
# Title: 10 Most Controversial Anime Of All Time, Ranked
# Link: https://www.cbr.com//most-controversial-anime-ever-ranked/
# Date: 2023-09-20
#
# Title: The 20 Most Evil Anime Villains Ever, Ranked
# Link: https://www.cbr.com//most-evil-anime-villains-ever-ranked/
# Date: 2023-09-20
#
# Title: My Happy Marriage Announces Season 2
# Link: https://www.cbr.com//my-happy-marriage-second-season/
# Date: 2023-09-20
#
# Title: 10 Anime Moments That Completely Changed Everything
# Link: https://www.cbr.com//anime-best-moments-changed-everything/
#
# Title: Telling a compelling story with data dashboards
# Link: https://datawrites.hashnode.dev/telling-a-compelling-story-with-data-dashboards
# Date: Sep 19, 2023
#
#
# Interesting Engineering:
# Title: ChatGPT's crypto token makes $12 million in trading on day 1
# Link: https://interestingengineering.com/culture/chatgpts-crypto-token-12-million
# Date: just now
#
# Title: Israel has unveiled its AI-assisted next-gen 'Merkava' tank
# Link: https://interestingengineering.com/military/israel-ai-assisted-next-gen-merkava
# Date: 1 hour ago
#
# Title: New quantum magnetometer to map Earth’s magnetic field from space
# Link: https://interestingengineering.com/innovation/new-quantum-magnetometer-to-map-earths-magnetic-field-from-space
# Date: 2 hours ago
#
# Title: 'Aliens' displayed in Mexico are from a single skeleton
# Link: https://interestingengineering.com/culture/aliens-displayed-in-mexico-are-from-a-single-skeleton
# Date: 2 hours ago
#
# Title: Black holes scarf up matter at dizzying speeds, says study
# Link: https://interestingengineering.com/science/black-holes-matter-dizzying-speeds
# Date: 8 hours ago
#
# Title: NASA aims to destroy an Empire State Building-sized asteroid
# Link: https://interestingengineering.com/science/nasa-bennu-asteroid-deflect
# Date: 13 hours ago
#
# Title: In a first, scientists light up blue LED with an AA battery
# Link: https://interestingengineering.com/innovation/blue-led-ultralow-turn-on-voltage
# Date: 15 hours ago
#
# Title: Cooler temperatures may help to extend EV-battery life
# Link: https://interestingengineering.com/transportation/cooler-temperatures-may-help-to-extend-ev-battery-life
# Date: 17 hours ago
#
# Title: DALL-E 3 coming in October, prompt engineering not required
# Link: https://interestingengineering.com/innovation/dall-e-3-coming-in-october-prompt-engineering-not-required
# Date: 17 hours ago
#
#
# Wired/Science:
# Title: The US Is Mobilizing an Army to Fight the Climate Crisis
# Link: https://www.wired.com/story/the-us-is-mobilizing-an-army-to-fight-the-climate-crisis/
# Category: Front Lines
#
# Title: Everything You Need to Know About Getting Your Genome Sequenced
# Link: https://www.wired.com/story/everything-you-need-to-know-about-getting-your-genome-sequenced/
# Category: WIRED30
#
# Title: The Gruesome Story of How Neuralink’s Monkeys Actually Died
# Link: https://www.wired.com/story/elon-musk-pcrm-neuralink-monkey-deaths/
# Category: Test Case
#
# Title: High Blood Pressure Is the World’s Biggest Killer. Now There’s a Plan to Tackle It
# Link: https://www.wired.com/story/high-blood-pressure-is-the-worlds-biggest-killer-now-theres-a-plan-to-tackle-it/
# Category: N/A
#
# Title: DeepMind’s New AI Can Predict Genetic Diseases
# Link: https://www.wired.com/story/deepmind-ai-alphamissense-genetics-rare-diseases/
# Category: N/A
#
# Title: This Is Your Kid’s Brain on Extreme Heat
# Link: https://www.wired.com/story/extreme-heat-kids-schools-learning/
# Category: N/A
#
# Title: Serious Brain Trauma Starts Well Before Young Athletes Go Pro
# Link: https://www.wired.com/story/serious-brain-trauma-starts-well-before-young-athletes-go-pro/
# Category: N/A
#
# Title: A Pair of Sun Probes Just Got Closer to Solving a Solar Enigma
# Link: https://www.wired.com/story/a-pair-of-sun-probes-just-got-closer-to-solving-a-solar-enigma/
# Category: N/A
#
# Title: NASA Didn’t Find Aliens—but if You See Any UFOs, Holler
# Link: https://www.wired.com/story/nasa-ufos-aliens-report-2023/
# Link: https://www.wired.com/story/a-flesh-eating-bacterium-is-creeping-north-as-oceans-warm/
# Category: Public Health
#
# Title: Ozempic and Wegovy Can Also Protect Your Heart
# Link: https://www.wired.com/story/weight-loss-drugs-ozempic-and-wegovy-can-also-protect-the-heart/
# Category: Public Health
#
# Title: A Billion-Dollar Plan to Fix Farm Emissions Might Make Things Worse
# Link: https://www.wired.com/story/usda-climate-smart-agriculture/
# Category: Seeds of Doubt
#
# Title: Climate Change Has Finally Come for Burning Man
# Link: https://www.wired.com/story/climate-change-has-finally-come-for-burning-man/
# Category: Drowning Man
#
# Title: 7 Face Masks Your Kids May Actually Wear
# Link: https://www.wired.com/gallery/best-kids-face-masks/
# Category: Buying Guide
#
# Title: What Ever Happened to the Tiny House Movement?
# Link: https://www.wired.com/story/what-ever-happened-to-the-tiny-house-movement/
# Category: Dream Small
#
# Title: Burying Power Lines Prevents Wildfires. But There’s a Cost
# Link: https://www.wired.com/story/the-high-stakes-calculus-of-preventing-wildfires-by-burying-power-lines/
# Category: Shock Value
#
# Title: Sorry, Your Paper Coffee Cup Is a Toxic Nightmare
# Link: https://www.wired.com/story/paper-cups-toxic/
# Category: Poisoned Chalice
#
# Title: DART Showed How to Smash an Asteroid. So Where Did the Space Shrapnel Go?
# Link: https://www.wired.com/story/dart-showed-how-to-smash-an-asteroid-so-where-did-the-space-shrapnel-go/
# Category: Hit It
#
# Title: Turtles Carry Signs of Humanity’s Nuclear History in Their Shells
# Link: https://www.wired.com/story/turtles-carry-signs-of-humanitys-nuclear-history-in-their-shells/
# Category: Tough Stuff
#
# Title: Hurricane Idalia Is About to Slam Florida With a Wall of Water
# Link: https://www.wired.com/story/hurricane-idalia-is-about-to-slam-florida-with-a-wall-of-water/
# Category: Storm Surge
#
# Title: The Massive Campaign to Air-Drop Tiny Rabies Vaccines to Raccoons
# Link: https://www.wired.com/story/the-massive-campaign-to-air-drop-tiny-rabies-vaccines-to-raccoons/
# Category: Special Delivery
#
#
# TechCrunch/Startups:
# Title: Here are the 6 finalists of Startup Battlefield at Disrupt 2023
# Link: https://techcrunch.com/2023/09/20/here-are-the-6-finalists-of-startup-battlefield-at-disrupt-2023/
# Date:
# 		Sep 20, 2023
#
# Title: Auctoria uses generative AI to create video game models
# Link: https://techcrunch.com/2023/09/20/auctoria-uses-generative-ai-to-create-video-game-models/
# Date:
# 		Sep 20, 2023
#
# Title: PureSpace prevents spoiled produce by removing ripening gas
# Link: https://techcrunch.com/2023/09/20/purespace-prevents-spoiled-produce-by-removing-ripening-gas/
# Date:
# 		Sep 20, 2023
#
# Title: MakersHub deciphers accounts payable data so construction companies don’t have to
# Link: https://techcrunch.com/2023/09/20/makershub-accounts-payable-data-construction-battlefield/
# Date:
# 		Sep 20, 2023
#
# Title: Agtech leaders dish on untapped and overlooked opportunities for founders
# Link: https://techcrunch.com/2023/09/20/agtech-leaders-dish-on-untapped-and-overlooked-opportunities-for-founders/
# Date:
# 		Sep 20, 2023
#
# Title: Agri-Trak is helping farms replace pen and paper with digital tools to track labor and production
# Link: https://techcrunch.com/2023/09/20/agri-trak-is-helping-farms-replace-pen-and-paper-with-digital-tools-to-track-labor-and-production/
# Date:
# 		Sep 20, 2023
#
# Title: Why is Y Combinator so defensive lately?
# Link: https://techcrunch.com/2023/09/20/why-is-y-combinator-so-defensive-lately/
# Date:
# 		Sep 20, 2023
#
# Title: AppFactor drags legacy enterprise apps to the cloud through automation
# Link: https://techcrunch.com/2023/09/20/appfactor-drags-legacy-enterprise-apps-to-the-cloud-through-automation/
# Date:
# 		Sep 20, 2023
#
# Title: Alpha3D wants to accelerate digital asset and AI-powered generation through cheaper, hyperscaling technology
# Link: https://techcrunch.com/2023/09/20/alpha3d-wants-to-accelerate-digital-asset-and-ai-powered-generation-through-cheaper-hyper-scaling-technology/
# Date:
# 		Sep 20, 2023
#
# Title: JusticeText taps AI to transcribe evidence for public defenders
# Link: https://techcrunch.com/2023/09/20/justicetext-taps-ai-to-transcribe-evidence-for-public-defenders/
# Date:
# 		Sep 20, 2023
#
# Title: Clika is building a platform to make AI models run faster
# Link: https://techcrunch.com/2023/09/20/clika-is-building-a-platform-to-make-ai-models-run-faster/
# Date:
# 		Sep 20, 2023
#
# Title: Petnow claims to be able to identify dogs and cats from their snouts
# Link: https://techcrunch.com/2023/09/20/petnow-claims-to-be-able-to-identify-dogs-and-cats-from-their-snouts/
# Date:
# 		Sep 20, 2023
#
# Title: Will the American Climate Corps program be enough to meet the wave of jobs coming up in climate tech?
# Link: https://techcrunch.com/2023/09/20/american-climate-corps-climatetech-labor/
# Date:
# 		Sep 20, 2023
#
# Title: PDS is coming to a cop car near you to stop you from drug-driving
# Link: https://techcrunch.com/2023/09/20/portable-diagnostic-systems-prototype-ready-for-launch/
# Date:
# 		Sep 20, 2023
#
# Title: Capsule introduces its AI-powered video editor for enterprise teams
# Link: https://techcrunch.com/2023/09/20/capsule-introduces-its-ai-powered-video-editor-for-enterprise-teams/
# Date:
# 		Sep 20, 2023
#
# Title: Mainstack’s no-code online business service eliminates cross-border payment complexity
# Link: https://techcrunch.com/2023/09/20/mainstacks-no-code-online-business-service-eliminates-cross-border-payment-complexity/
# Date:
# 		Sep 20, 2023
#
# Title: Untap Health wants to help offices and care homes track risk from bugs like flu and COVID-19
# Link: https://techcrunch.com/2023/09/20/untap-health/
# Date:
# 		Sep 20, 2023
#
# Title: Don’t use builds, reveals or animations in your pitch deck
# Link: https://techcrunch.com/2023/09/20/dont-use-builds-reveals-or-animations-in-your-pitch-deck/
# Date:
# 		Sep 20, 2023
#
# Title: Roblox acquires voice moderation startup Speechly
# Link: https://techcrunch.com/2023/09/20/roblox-acquires-voice-moderation-startup-speechly/
# Date:
# 		Sep 20, 2023
#
# Title: Equity Live: Self-flying helicopters, AI and the battle of the features
# Link: https://techcrunch.com/2023/09/20/equity-live-self-flying-helicopters-ai-and-the-battle-of-the-features/
# Date:
# 		Sep 20, 2023

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin  # Import urljoin

def scrape_cbr_anime():
    print("--------------------------------")
    print("CBR/Anime")
    print("--------------------------------")

    # Replace 'your_url_here' with the actual URL of the website you want to scrape
    url = 'https://www.cbr.com/category/anime/'  # Replace with the actual URL

    # Send an HTTP GET request to the website
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find and print the titles, links, and dates of the articles
        article_blocks = soup.find_all('div', class_='w-display-card-content')  # Replace with the actual HTML element and class name
        for block in article_blocks:
            title_element = block.find('h5', class_='display-card-title').find('a')
            title = title_element.text.strip()
            relative_link = title_element['href']  # Get the relative link
            full_link = urljoin(url, relative_link)  # Prepend base URL to relative links
            date_element = block.find('time', class_='display-card-date')['datetime']
            date = date_element.split('T')[0]  # Extract date part from the datetime attribute
            print(f"Title: {title}")
            print(f"Link: {full_link}")  # Use the full link with the base URL
            print(f"Date: {date}")
            print()  # Add an empty line for better readability
    else:
        print('Failed to retrieve the webpage. Status code:', response.status_code)

def scrape_hashnode_data_science():
    print("--------------------------------")
    print("Hashnode/Data Science")
    print("--------------------------------")

    # Replace 'your_url_here' with the actual URL of the website you want to scrape
    url = 'https://hashnode.com/n/data-science'  # Replace with the actual URL

    # Send an HTTP GET request to the website
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find and print the post titles, URLs, and dates
        post_sections = soup.find_all('section', class_='flex flex-col gap-2 sm:gap-4')  # Replace with the actual HTML element and class name
        for section in post_sections:
            title_element = section.find('h1', class_='font-heading text-base sm:text-xl font-semibold sm:font-bold text-slate-700 dark:text-slate-200 hn-break-words cursor-pointer')
            title = title_element.text.strip()
            link_element = title_element.find_parent('a', href=True)
            link = link_element['href']
            date_element = section.find('p', class_='text-sm text-slate-500 dark:text-slate-400 font-normal')
            date = date_element.text.strip()
            print(f"Title: {title}")
            print(f"Link: {link}")
            print(f"Date: {date}")
            print()  # Add an empty line for better readability
    else:
        print('Failed to retrieve the webpage. Status code:', response.status_code)

# Define similar functions for the other sites (TechCrunch, Interesting Engineering, Wired/Science)

def scrape_techcrunch_startups():
    print("--------------------------------")
    print("TechCrunch/Startups")
    print("--------------------------------")

    # Replace 'your_url_here' with the actual URL of the website you want to scrape
    url = 'https://techcrunch.com/category/startups/'

    # Send an HTTP GET request to the website
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find and print the titles, links, and dates of the blog posts
        post_blocks = soup.find_all('div', class_='post-block')  # Replace with the actual HTML element and class name
        for block in post_blocks:
            title = block.find('h2', class_='post-block__title').text.strip()
            link = block.find('a', class_='post-block__title__link')['href']
            date_element = block.find('time')
            date = date_element.text  # Extract date part from the datetime attribute
            print(f"Title: {title}")
            print(f"Link: {link}")
            print(f"Date: {date}")
            print()  # Add an empty line for better readability
    else:
        print('Failed to retrieve the webpage. Status code:', response.status_code)

def scrape_interesting_engineering():
    print("--------------------------------")
    print("Interesting Engineering")
    print("--------------------------------")

    # Base URL to prepend to relative links
    base_url = 'https://interestingengineering.com/'

    # Replace 'your_url_here' with the actual URL of the website you want to scrape
    url = 'https://interestingengineering.com/news/page/1'  # Replace with the actual URL

    # Send an HTTP GET request to the website
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find and print the article titles, URLs, and date information
        article_blocks = soup.find_all('div', class_='Category_result__description__iz_rw')  # Replace with the actual HTML element and class name
        for block in article_blocks:
            title_link_element = block.find('a', href=True)
            title = title_link_element.find('h2', class_='Category_result__header__HQgVv').text.strip()
            link = urljoin(base_url, title_link_element['href'])  # Prepend base URL to relative links
            author_element = block.find('a', class_='Category_result__author__name__In7jd')
            author = author_element.text.strip()
            date_element = block.find('span', class_='Category_result__author__publishTime__nwLBU')
            date = date_element.text.strip()
            print(f"Title: {title}")
            print(f"Link: {link}")
            print(f"Author: {author}")
            print(f"Date: {date}")
            print()  # Add an empty line for better readability
    else:
        print('Failed to retrieve the webpage. Status code:', response.status_code)

def scrape_wired_science():
    print("--------------------------------")
    print("Wired/Science")
    print("--------------------------------")

    # Replace 'your_url_here' with the actual URL of the website you want to scrape
    url = 'https://www.wired.com/category/science/'  # Replace with the actual URL

    # Send an HTTP GET request to the website
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find and print the article titles, URLs, and categories
        article_blocks = soup.find_all('div', class_='SummaryItemContent-eiDYMl')  # Replace with the actual HTML element and class name
        for block in article_blocks:
            title_element = block.find('h3', class_='SummaryItemHedBase-hiFYpQ')
            title = title_element.text.strip()
            relative_link = block.find('a', class_='SummaryItemHedLink-civMjp')['href']  # Get the relative link
            full_link = urljoin(url, relative_link)  # Prepend base URL to relative links
            category_element = block.find('span', class_='RubricName-fVtemz')
            category = category_element.text.strip() if category_element else "N/A"  # Handle missing category
            print(f"Title: {title}")
            print(f"Link: {full_link}")  # Use the full link with the base URL
            print(f"Category: {category}")
            print()  # Add an empty line for better readability
    else:
        print('Failed to retrieve the webpage. Status code:', response.status_code)

# Call the scraping functions for each site
scrape_cbr_anime()
scrape_hashnode_data_science()
scrape_interesting_engineering()
scrape_wired_science()
scrape_techcrunch_startups()
# Out:
# --------------------------------
# CBR/Anime
# --------------------------------
# Title: 10 Best Anime You Can Watch Right Now & Where to Stream Them
# Link: https://www.cbr.com/best-anime-available-right-now-where-to-watch/
# Date: 2023-09-23
#
# Title: 10 Magical Girl Anime With the Best Fight Scenes, Ranked
# Link: https://www.cbr.com/magical-girl-anime-best-fight-scenes-ranked/
# Date: 2023-09-23
#
# Title: Megumi Fushiguro and His Adorable Shikigami Train Together in New Jujutsu Kaisen Collectible
# Link: https://www.cbr.com/new-jjk-collectible-megumi-fushiguro-cute-shikigami-training/
# Date: 2023-09-23
#
# Title: The Eminence in Shadow Season 2 Simulcast of the English Dub Confirmed
# Link: https://www.cbr.com/the-eminence-in-shadow-s2-simulcast-english-dub-confirmed/
# Date: 2023-09-23
#
# Title: 10 Lessons Dragon Ball Super Should Learn From DBGT
# Link: https://www.cbr.com/lessons-dbs-should-learn-from-dbgt/
# Date: 2023-09-23
#
# Title: Butareba Anime Introduces Main Character in New Promotional Video
# Link: https://www.cbr.com/butareba-anime-introduces-main-character-new-promo-video/
# Date: 2023-09-23
#
# Title: 10 OG Dragon Ball Characters Who'd Be As Strong As A Super Saiyan if They Kept Training
# Link: https://www.cbr.com/original-db-characters-who-could-have-super-saiyan-strength/
# Date: 2023-09-23
#
# Title: Why Are So Many Anime Characters Kuudere?
# Link: https://www.cbr.com/kuudere-anime-characters-explained/
# Date: 2023-09-23
#
# Title: 10 Iconic Anime Villains Who Would've Won in Any Other Series
# Link: https://www.cbr.com/anime-villain-icons-would-win-in-another-series/
# Date: 2023-09-23
#
# Title: Boruto: Two Blue Vortex Teases the Evolution of the Rasengan In a Scary Way
# Link: https://www.cbr.com/boruto-two-blue-vortex-tease-rasengan-evolution-scarily/
# Date: 2023-09-23
#
# Title: 10 Anime Characters Who Are Kylo Ren In A Different Font
# Link: https://www.cbr.com/anime-characters-just-like-kylo-ren-star-wars/
# Date: 2023-09-23
#
# Title: Every Time A Straw Hat Pirate Left The Crew In One Piece (& Why)
# Link: https://www.cbr.com/one-piece-every-time-straw-hat-pirate-left-crew-why/
# Date: 2023-09-23
#
# Title: Bleach: Giselle Gewelle Might Actually Be the Strongest Sternritter
# Link: https://www.cbr.com/bleach-giselle-gewelle-strongest-sternritter/
# Date: 2023-09-23
#
# Title: 10 Dumbest Attack On Titan Villains
# Link: https://www.cbr.com/dumbest-aot-villains/
# Date: 2023-09-23
#
# Title: Boruto's Time Skip Is Better Than Naruto's
# Link: https://www.cbr.com/boruto-time-skip-better-than-naruto/
# Date: 2023-09-23
#
# Title: Dragon Ball: Every Eternal Dragon, Ranked by Coolness
# Link: https://www.cbr.com/dragon-ball-eternal-dragons-ranked/
# Date: 2023-09-23
#
# Title: Boruto: Two Blue Vortex Confirms [Spoiler] Is Darker — And It May Be Sasuke's Fault
# Link: https://www.cbr.com/boruto-two-blue-vortex-sasuke-dark-mentorship-kill-code/
# Date: 2023-09-23
#
# Title: Every Bleach Filler Arc (In Chronological Order)
# Link: https://www.cbr.com/bleach-anime-filler-arc-chronological-order/
# Date: 2023-09-23
#
# Title: 10 Most Powerful Anime Dragons of All Time, Ranked
# Link: https://www.cbr.com/strongest-anime-dragons-ranked/
# Date: 2023-09-23
#
# Title: Saint Seiya: Where the Spin-Offs Fit in the Timeline Chronologically
# Link: https://www.cbr.com/saint-seiya-where-spin-offs-fit-chronologically/
# Date: 2023-09-23
#
# --------------------------------
# Hashnode/Data Science
# --------------------------------
# Title: Explore some basic definition of AI and its subsets
# Link: https://everthingaboutdata.hashnode.dev/explore-some-basic-definition-of-ai-and-its-subsets
# Date: 3 hours ago
#
# Title: Python for Data Science: A Roadmap to Follow
# Link: https://sazidthe1.hashnode.dev/python-for-data-science-a-roadmap-to-follow
# Date: 5 hours ago
#
# Title: How to Compress AI Data Flow
# Link: https://donwolfonline.hashnode.dev/how-to-compress-ai-data-flow
# Date: 20 hours ago
#
# Title: LongLoRA: A New, More Efficient Way to Fine-Tune LLMs
# Link: https://mikeyoung44.hashnode.dev/longlora-a-new-more-efficient-way-to-fine-tune-llms
# Date: Sep 22, 2023
#
# Title: Bringing Still Pictures to Life with Neural Motion Textures
# Link: https://mikeyoung44.hashnode.dev/bringing-still-pictures-to-life-with-neural-motion-textures
# Date: Sep 22, 2023
#
# Title: Why Kafka Is the New Data Lake?
# Link: https://risingwavelabs.hashnode.dev/why-kafka-is-the-new-data-lake
# Date: Sep 22, 2023
#
# Title: "DPLYR" -The Data Manipulator
# Link: https://timiranalyst.hashnode.dev/dplyr-the-data-manipulator
# Date: Sep 22, 2023
#
# Title: How to Create Stunning Charts with Matplotlib
# Link: https://edetjoseph.hashnode.dev/how-to-create-stunning-charts-with-matplotlib
# Date: Sep 21, 2023
#
# Title: Data Structures using Python
# Link: https://tomandjerry-blogs.hashnode.dev/data-structures-using-python
# Date: Sep 21, 2023
#
# Link: https://www.wired.com/story/cosmic-neutrinos-origin/
# Category: N/A
#
# Title: How to Cool an Object Without Using Any Energy
# Link: https://www.wired.com/story/how-to-cool-an-object-without-using-any-energy/
# Category: N/A
#
# Title: The Lawlessness of Large Numbers
# Link: https://www.wired.com/story/the-lawlessness-of-large-numbers/
# Category: N/A
#
# Title: The Gruesome Story of How Neuralink’s Monkeys Actually Died
# Link: https://www.wired.com/story/elon-musk-pcrm-neuralink-monkey-deaths/
# Category: N/A
#
# Title: Everything We Know About Neuralink’s Brain Implant Trial
# Link: https://www.wired.com/story/everything-we-know-about-neuralinks-brain-implant-trial/
# Category: N/A
#
# Title: Here Come the Glow-in-the-Dark Houseplants
# Link: https://www.wired.com/story/here-come-the-glow-in-the-dark-houseplants/
# Category: N/A
#
# Title: Crispr Pioneer Jennifer Doudna Has the Guts to Take On the Microbiome
# Link: https://www.wired.com/story/crispr-jennifer-doudna-microbiome/
# Category: N/A
#
# Title: AI Is Building Highly Effective Antibodies That Humans Can’t Even Imagine
# Link: https://www.wired.com/story/labgenius-antibody-factory-machine-learning/
# Category: N/A
#
# Title: This Artificial Muscle Moves Stuff on Its Own
# Link: https://www.wired.com/story/this-artificial-muscle-moves-stuff-on-its-own/
# Category: N/A
#
# Title: Get Ready for 3D-Printed Organs and a Knife That ‘Smells’ Tumors
# Link: https://www.wired.com/story/medical-innovations-hospital-future/
# Category: N/A
#
# Title: Rovers Are So Yesterday. It’s Time to Send a Snakebot to Space
# Link: https://www.wired.com/story/rovers-are-so-yesterday-its-time-to-send-a-snakebot-to-space/
# Category: N/A
#
# Title: Is It Real or Imagined? Here’s How Your Brain Tells the Difference
# Link: https://www.wired.com/story/is-it-real-or-imagined-heres-how-your-brain-tells-the-difference/
# Category: N/A
#
# Title: Brain Implants That Help Paralyzed People Speak Just Broke New Records
# Link: https://www.wired.com/story/brain-implants-that-help-paralyzed-people-speak-just-broke-new-records/
# Category: N/A
#
# Title: Use of AI Is Seeping Into Academic Journals—and It’s Proving Difficult to Detect
# Link: https://www.wired.com/story/use-of-ai-is-seeping-into-academic-journals-and-its-proving-difficult-to-detect/
# Category: N/A
#
# Title: Everyone Was Wrong About Antipsychotics
# Link: https://www.wired.com/story/everyone-was-wrong-about-antipsychotics/
# Category: N/A
#
# Title: A Global Surge in Cholera Outbreaks May Be Fueled by Climate Change
# Link: https://www.wired.com/story/a-global-surge-in-cholera-outbreaks-may-be-fueled-by-climate-change/
# Category: Public Health
#
# Title: This Is Your Kid’s Brain on Extreme Heat
# Link: https://www.wired.com/story/extreme-heat-kids-schools-learning/
# Category: Any Questions?
#
# Title: Insiders Reveal Major Problems at Lab-Grown-Meat Startup Upside Foods
# Link: https://www.wired.com/story/upside-foods-lab-grown-chicken/
# Category: Fake Meat
#
# Title: Libya’s Deadly Floods Show the Growing Threat of Medicanes
# Link: https://www.wired.com/story/libya-medicane-flooding-storm-daniel-derma/
# Category: Climate Crisis
#
# Title: No, This Is Not an Alien. Here’s Why
# Link: https://www.wired.com/story/mexico-congress-aliens-fake/
# Category: Phone Home
#
# Title: Scientists Say You’re Looking for Alien Civilizations All Wrong
# Link: https://www.wired.com/story/scientists-say-youre-looking-for-alien-civilizations-all-wrong/
# Category: Search Party
#
# Title: Covid Boosters Can’t Outpace New Mutations. Here’s Why They Still Work
# Link: https://www.wired.com/story/covid-vaccine-boosters-2023-moderna-pfizer/
# Category: Public Health
#
# Title: Serious Brain Trauma Starts Well Before Young Athletes Go Pro
# Link: https://www.wired.com/story/serious-brain-trauma-starts-well-before-young-athletes-go-pro/
# Category: Public Health
#
# Title: Yes, There’s a New Covid Variant. No, You Shouldn’t Panic
# Link: https://www.wired.com/story/pirola-covid-variant/
# Category: Public Health
#
# Title: Rivers Are Drowning in Toxic Sludge
# Link: https://www.wired.com/story/blue-green-algae-is-filling-rivers-with-toxic-sludge/
# Category: Growth Spurt
#
# Title: A Summer of Record Heat Deals Costly Damage to Texas Water Systems
# Link: https://www.wired.com/story/a-summer-of-record-heat-deals-costly-damage-to-texas-water-systems/
# Category: Hot Button
#
# Title: SpaceX Must Fix 63 Issues Before Its Starship Can Fly Again
# Link: https://www.wired.com/story/the-investigation-of-spacexs-starship-explosion-is-complete-and-elon-musk-has-more-work-to-do/
# Category: Grounded
#
# Title: The Rapid Intensification of Hurricane Lee Is a Warning
# Link: https://www.wired.com/story/the-rapid-intensification-of-hurricane-lee-is-a-warning/
# Category: Climate Change
#
# Title: Scientists Just Tried Growing Human Kidneys in Pigs
# Link: https://www.wired.com/story/scientists-just-tried-growing-human-kidneys-in-pigs/
# Category: Building Blocks
#
# Title: A Flesh-Eating Bacterium Is Creeping North as Oceans Warm
# Link: https://www.wired.com/story/a-flesh-eating-bacterium-is-creeping-north-as-oceans-warm/
# Category: Public Health
#
# Title: Ozempic and Wegovy Can Also Protect Your Heart
# Link: https://www.wired.com/story/weight-loss-drugs-ozempic-and-wegovy-can-also-protect-the-heart/
# Category: Public Health
#
# Title: A Billion-Dollar Plan to Fix Farm Emissions Might Make Things Worse
# Link: https://www.wired.com/story/usda-climate-smart-agriculture/
# Category: Seeds of Doubt
#
# Title: Climate Change Has Finally Come for Burning Man
# Link: https://www.wired.com/story/climate-change-has-finally-come-for-burning-man/
# Category: Drowning Man
#
# Title: 7 Face Masks Your Kids May Actually Wear
# Link: https://www.wired.com/gallery/best-kids-face-masks/
# Category: Buying Guide
#
# Title: What Ever Happened to the Tiny House Movement?
# Link: https://www.wired.com/story/what-ever-happened-to-the-tiny-house-movement/
# Category: Dream Small
#
# --------------------------------
# TechCrunch/Startups
# --------------------------------
# Title: Disability tech startups kill the cynic in me
# Link: https://techcrunch.com/2023/09/23/disability-tech-startup-battlefield/
# Date:
# 		Sep 23, 2023
#
# Title: Bay Area baby belly beholding Battlefield bounty
# Link: https://techcrunch.com/2023/09/22/bay-area-baby-belly-beholding-battlefield-bounty/
# Date:
# 		Sep 22, 2023
#
# Title: Pitch Deck Teardown: Transcend’s $20M Series B deck
# Link: https://techcrunch.com/2023/09/22/sample-series-b-pitch-deck-transcend/
# Date:
# 		Sep 22, 2023
#
# Title: TechCrunch+ Roundup: Prompt engineering, web3 gaming survey, how to spend $10K on paid ads
# Link: https://techcrunch.com/2023/09/22/techcrunch-roundup-prompt-engineering-web3-gaming-survey-how-to-spend-10k-on-paid-ads/
# Date:
# 		Sep 22, 2023
#
# Title: South Africa’s FinanceGPT simplifies financial analysis, set to interface in local languages
# Link: https://techcrunch.com/2023/09/22/financegpt-generative-ai-tools-for-financial-analysis/
# Date:
# 		Sep 22, 2023
#
# Title: HME Square aims to measure glucose painlessly with photoacoustics
# Link: https://techcrunch.com/2023/09/21/hme-square-aims-to-measure-glucose-painlessly-with-photoacoustics/
# Date:
# 		Sep 21, 2023
#
# Title: Communia hopes to build a digital safe space for women
# Link: https://techcrunch.com/2023/09/21/communia-hopes-to-build-a-digital-safe-space-for-women/
# Date:
# 		Sep 21, 2023
#
# Title: And the winner of Startup Battlefield at Disrupt 2023 is . . . BioticsAI
# Link: https://techcrunch.com/2023/09/21/startup-battlefield-winner-techcrunch-disrupt-2023/
# Date:
# 		Sep 21, 2023
#
# Title: Inside Kinhub’s plan to democratize employee wellness
# Link: https://techcrunch.com/2023/09/21/inside-kinhubs-plan-to-democratize-employee-wellness/
# Date:
# 		Sep 21, 2023
#
# Title: eStreamly blends physical, digital shopping with the video as the star
# Link: https://techcrunch.com/2023/09/21/estreamly-livestream-shopping-battlefield/
# Date:
# 		Sep 21, 2023
#
# Title: AvantGuard wants to turn chlorine into the best antiseptic you’ve ever seen
# Link: https://techcrunch.com/2023/09/21/avantguard-chlorine-antiseptic-battlefield/
# Date:
# 		Sep 21, 2023
#
# Title: Don’t want that commuter stipend? Bundl enables employees to choose their own company benefits
# Link: https://techcrunch.com/2023/09/21/bundl-employee-benefits-battlefield/
# Date:
# 		Sep 21, 2023
#
# Title: AppCyclers wants to fight e-waste pollution across Africa
# Link: https://techcrunch.com/2023/09/21/appcyclers-wants-to-fight-e-waste-pollution-across-africa/
# Date:
# 		Sep 21, 2023
#
# Title: Qruise wants to build AI to automate quantum device development
# Link: https://techcrunch.com/2023/09/21/qruise-wants-to-build-ai-to-automate-quantum-device-development/
# Date:
# 		Sep 21, 2023
#
# Title: Artifact co-founder Kevin Systrom doesn’t believe in AI doomerism
# Link: https://techcrunch.com/2023/09/21/artifact-co-founder-kevin-systrom-doesnt-believe-in-ai-doomerism/
# Date:
# 		Sep 21, 2023
#
# Title: Secoda secures $14M to expand its data cataloging platform
# Link: https://techcrunch.com/2023/09/21/secoda-secures-16m-to-expand-its-data-cataloging-platform/
# Date:
# 		Sep 21, 2023
#
# Title: Banish cumulative graphs from your pitch deck
# Link: https://techcrunch.com/2023/09/21/no-cumulative-numbers/
# Date:
# 		Sep 21, 2023
#
# Title: Frontier Space Technologies is developing an on-orbit autonomous lab to make space science easy
# Link: https://techcrunch.com/2023/09/21/frontier-space-technologies-is-developing-an-on-orbit-autonomous-lab-to-make-space-science-easy/
# Date:
# 		Sep 21, 2023
#
# Title: How to spend your first $10K on paid ads
# Link: https://techcrunch.com/2023/09/21/how-to-spend-your-first-10k-on-paid-ads/
# Date:
# 		Sep 21, 2023
#
# Title: Mesh, which helps people manage their digital assets, raises $22M
# Link: https://techcrunch.com/2023/09/21/mesh-which-helps-people-manage-their-digital-assets-raises-22m/
# Date:
# 		Sep 21, 2023
