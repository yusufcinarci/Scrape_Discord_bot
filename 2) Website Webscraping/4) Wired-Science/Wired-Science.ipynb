# %%
import requests
from bs4 import BeautifulSoup

# Replace 'your_url_here' with the actual URL of the website you want to scrape
url = 'https://www.wired.com/category/science/'  # Replace with the actual URL

# Send an HTTP GET request to the website
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find and print the article titles, URLs, and categories
    article_blocks = soup.find_all('div', class_='SummaryItemContent-eiDYMl')  # Replace with the actual HTML element and class name
    for block in article_blocks:
        title_element = block.find('h3', class_='SummaryItemHedBase-hiFYpQ')
        title = title_element.text.strip()
        link_element = block.find('a', class_='SummaryItemHedLink-civMjp')
        link = link_element['href']
        category_element = block.find('span', class_='RubricName-fVtemz')
        category = category_element.text.strip() if category_element else "N/A"  # Handle missing category
        print(f"Title: {title}")
        print(f"Link: {link}")
        print(f"Category: {category}")
        print()  # Add an empty line for better readability
else:
    print('Failed to retrieve the webpage. Status code:', response.status_code)
# Out:
# Title: The US Is Mobilizing an Army to Fight the Climate Crisis
# Link: /story/the-us-is-mobilizing-an-army-to-fight-the-climate-crisis/
# Category: Front Lines
#
# Title: Everything You Need to Know About Getting Your Genome Sequenced
# Link: /story/everything-you-need-to-know-about-getting-your-genome-sequenced/
# Category: WIRED30
#
# Title: The Gruesome Story of How Neuralink’s Monkeys Actually Died
# Link: /story/elon-musk-pcrm-neuralink-monkey-deaths/
# Category: Test Case
#
# Title: High Blood Pressure Is the World’s Biggest Killer. Now There’s a Plan to Tackle It
# Link: /story/high-blood-pressure-is-the-worlds-biggest-killer-now-theres-a-plan-to-tackle-it/
# Category: N/A
#
# Title: DeepMind’s New AI Can Predict Genetic Diseases
# Link: /story/deepmind-ai-alphamissense-genetics-rare-diseases/
# Category: N/A
#
# Title: This Is Your Kid’s Brain on Extreme Heat
# Link: /story/extreme-heat-kids-schools-learning/
# Category: N/A
#
# Title: Serious Brain Trauma Starts Well Before Young Athletes Go Pro
# Link: /story/serious-brain-trauma-starts-well-before-young-athletes-go-pro/
# Category: N/A
#
# Title: A Pair of Sun Probes Just Got Closer to Solving a Solar Enigma
# Link: /story/a-pair-of-sun-probes-just-got-closer-to-solving-a-solar-enigma/
# Category: N/A
#
# Title: NASA Didn’t Find Aliens—but if You See Any UFOs, Holler
# Link: /story/nasa-ufos-aliens-report-2023/
# Category: N/A
#
# Title: No, This Is Not an Alien. Here’s Why
# Link: /story/mexico-congress-aliens-fake/
# Category: N/A
#
# Title: Scientists Say You’re Looking for Alien Civilizations All Wrong
# Link: /story/scientists-say-youre-looking-for-alien-civilizations-all-wrong/
# Category: N/A
#
# Title: Explore the Ancient Aztec Capital in This Lifelike 3D Rendering
# Link: /story/explore-tenochtitlan-ancient-aztec-capital-3d-render-thomas-kole/
# Category: N/A
#
# Title: This Treaty Could Stop Plastic Pollution—or Doom the Earth to Drown in It
# Link: /story/this-treaty-could-stop-plastic-pollution-or-doom-the-earth-to-drown-in-it/
# Category: N/A
#
# Title: Why Some Animals Thrive in Cities
# Link: /story/urban-animals-wildlife-biodiversity-traits-pigeons-reptiles-amphibians/
# Category: N/A
#
# Title: In a Fierce Desert, Microbe ‘Crusts’ Show How Life Tamed the Land
# Link: /story/in-a-fierce-desert-microbe-crusts-show-how-life-tamed-the-land/
# Category: N/A
#
# Title: The UK Is Burning Climate Pledges to Fuel a Culture War
# Link: /story/uk-net-zero-climate-pledges-weakened-rishi-sunak/
# Category: N/A
#
# Title: The Mysterious 'Warming Hole' in the Middle of the US
# Link: /story/the-mysterious-warming-hole-in-the-middle-of-the-us/
# Category: N/A
#
# Title: Ski Resorts Are Giving Up on Snow
# Link: /story/ski-adaptations-climate-change-paganella-italy/
# Category: N/A
#
# Title: A Global Surge in Cholera Outbreaks May Be Fueled by Climate Change
# Link: /story/a-global-surge-in-cholera-outbreaks-may-be-fueled-by-climate-change/
# Category: N/A
#
# Title: Radiation Is Everywhere. But It’s Not All Bad
# Link: /story/radiation-is-everywhere-but-its-not-all-bad/
# Category: N/A
#
# Title: Electrifying Your Home Is About to Get a Lot Cheaper
# Link: /story/electrifying-your-home-is-about-to-get-a-lot-cheaper/
# Category: N/A
#
# Title: Your New Apple Watch Won’t Be Carbon Neutral
# Link: /story/new-apple-watch-series-9-wont-be-carbon-neutral/
# Category: N/A
#
# Title: Big Batteries Are Booming. So Are Fears They'll Catch Fire
# Link: /story/big-grid-batteries-are-booming-so-are-fears-fire/
# Category: N/A
#
# Title: A New Proof Moves the Needle on a Sticky Geometry Problem
# Link: /story/a-new-proof-moves-the-needle-on-a-sticky-geometry-problem/
# Category: N/A
#
# Title: A New Map of the Universe, Painted With Cosmic Neutrinos
# Link: /story/cosmic-neutrinos-origin/
# Category: N/A
#
# Title: How to Cool an Object Without Using Any Energy
# Link: /story/how-to-cool-an-object-without-using-any-energy/
# Category: N/A
#
# Title: The Lawlessness of Large Numbers
# Link: /story/the-lawlessness-of-large-numbers/
# Category: N/A
#
# Title: Everything We Know About Neuralink’s Brain Implant Trial
# Link: /story/everything-we-know-about-neuralinks-brain-implant-trial/
# Category: N/A
#
# Title: Here Come the Glow-in-the-Dark Houseplants
# Link: /story/here-come-the-glow-in-the-dark-houseplants/
# Category: N/A
#
# Title: Crispr Pioneer Jennifer Doudna Has the Guts to Take On the Microbiome
# Link: /story/crispr-jennifer-doudna-microbiome/
# Category: N/A
#
# Title: Covid Boosters Can’t Outpace New Mutations. Here’s Why They Still Work
# Link: /story/covid-vaccine-boosters-2023-moderna-pfizer/
# Category: N/A
#
# Title: AI Is Building Highly Effective Antibodies That Humans Can’t Even Imagine
# Link: /story/labgenius-antibody-factory-machine-learning/
# Category: N/A
#
# Title: This Artificial Muscle Moves Stuff on Its Own
# Link: /story/this-artificial-muscle-moves-stuff-on-its-own/
# Category: N/A
#
# Title: Get Ready for 3D-Printed Organs and a Knife That ‘Smells’ Tumors
# Link: /story/medical-innovations-hospital-future/
# Category: N/A
#
# Title: Rovers Are So Yesterday. It’s Time to Send a Snakebot to Space
# Link: /story/rovers-are-so-yesterday-its-time-to-send-a-snakebot-to-space/
# Category: N/A
#
# Title: Is It Real or Imagined? Here’s How Your Brain Tells the Difference
# Link: /story/is-it-real-or-imagined-heres-how-your-brain-tells-the-difference/
# Category: N/A
#
# Title: Brain Implants That Help Paralyzed People Speak Just Broke New Records
# Link: /story/brain-implants-that-help-paralyzed-people-speak-just-broke-new-records/
# Category: N/A
#
# Title: Use of AI Is Seeping Into Academic Journals—and It’s Proving Difficult to Detect
# Link: /story/use-of-ai-is-seeping-into-academic-journals-and-its-proving-difficult-to-detect/
# Category: N/A
#
# Title: Everyone Was Wrong About Antipsychotics
# Link: /story/everyone-was-wrong-about-antipsychotics/
# Category: N/A
#
# Title: Insiders Reveal Major Problems at Lab-Grown-Meat Startup Upside Foods
# Link: /story/upside-foods-lab-grown-chicken/
# Category: Fake Meat
#
# Title: Libya’s Deadly Floods Show the Growing Threat of Medicanes
# Link: /story/libya-medicane-flooding-storm-daniel-derma/
# Category: Climate Crisis
#
# Title: Yes, There’s a New Covid Variant. No, You Shouldn’t Panic
# Link: /story/pirola-covid-variant/
# Category: Public Health
#
# Title: Rivers Are Drowning in Toxic Sludge
# Link: /story/blue-green-algae-is-filling-rivers-with-toxic-sludge/
# Category: Growth Spurt
#
# Title: A Summer of Record Heat Deals Costly Damage to Texas Water Systems
# Link: /story/a-summer-of-record-heat-deals-costly-damage-to-texas-water-systems/
# Category: Hot Button
#
# Title: SpaceX Must Fix 63 Issues Before Its Starship Can Fly Again
# Link: /story/the-investigation-of-spacexs-starship-explosion-is-complete-and-elon-musk-has-more-work-to-do/
# Category: Grounded
#
# Title: The Rapid Intensification of Hurricane Lee Is a Warning
# Link: /story/the-rapid-intensification-of-hurricane-lee-is-a-warning/
# Category: Climate Change
#
# Title: Scientists Just Tried Growing Human Kidneys in Pigs
# Link: /story/scientists-just-tried-growing-human-kidneys-in-pigs/
# Category: Building Blocks
#
# Title: A Flesh-Eating Bacterium Is Creeping North as Oceans Warm
# Link: /story/a-flesh-eating-bacterium-is-creeping-north-as-oceans-warm/
# Category: Public Health
#
# Title: Ozempic and Wegovy Can Also Protect Your Heart
# Link: /story/weight-loss-drugs-ozempic-and-wegovy-can-also-protect-the-heart/
# Category: Public Health
#
# Title: A Billion-Dollar Plan to Fix Farm Emissions Might Make Things Worse
# Link: /story/usda-climate-smart-agriculture/
# Category: Seeds of Doubt
#
# Title: Climate Change Has Finally Come for Burning Man
# Link: /story/climate-change-has-finally-come-for-burning-man/
# Category: Drowning Man
#
# Title: 7 Face Masks Your Kids May Actually Wear
# Link: /gallery/best-kids-face-masks/
# Category: Buying Guide
#
# Title: What Ever Happened to the Tiny House Movement?
# Link: /story/what-ever-happened-to-the-tiny-house-movement/
# Category: Dream Small
#
# Title: Burying Power Lines Prevents Wildfires. But There’s a Cost
# Link: /story/the-high-stakes-calculus-of-preventing-wildfires-by-burying-power-lines/
# Category: Shock Value
#
# Title: Sorry, Your Paper Coffee Cup Is a Toxic Nightmare
# Link: /story/paper-cups-toxic/
# Category: Poisoned Chalice
#
# Title: DART Showed How to Smash an Asteroid. So Where Did the Space Shrapnel Go?
# Link: /story/dart-showed-how-to-smash-an-asteroid-so-where-did-the-space-shrapnel-go/
# Category: Hit It
#
# Title: Turtles Carry Signs of Humanity’s Nuclear History in Their Shells
# Link: /story/turtles-carry-signs-of-humanitys-nuclear-history-in-their-shells/
# Category: Tough Stuff
#
# Title: Hurricane Idalia Is About to Slam Florida With a Wall of Water
# Link: /story/hurricane-idalia-is-about-to-slam-florida-with-a-wall-of-water/
# Category: Storm Surge
#
# Title: The Massive Campaign to Air-Drop Tiny Rabies Vaccines to Raccoons
# Link: /story/the-massive-campaign-to-air-drop-tiny-rabies-vaccines-to-raccoons/
# Category: Special Delivery
